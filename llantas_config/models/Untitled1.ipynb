# %%
x = env['product.product'].search([('es_paquete','=',True)])
for product in x:
    try:
        product.write({
            'yuju_kit': product.bom_ids[0].id
        })
    except (UserError, ValidationError):
        print('error' + str(product.id))
# Out:
# 2024-11-01 23:25:28,459 1122 INFO invezomx-stag-15712346 odoo.addons.madkting.models.product: {'yuju_kit': 234380}
# 2024-11-01 23:25:28,459 1122 INFO invezomx-stag-15712346 odoo.addons.madkting.models.product: {'yuju_kit': 331075}
# 2024-11-01 23:25:28,459 1122 INFO invezomx-stag-15712346 odoo.addons.madkting.models.product: {'yuju_kit': 258082}
# 2024-11-01 23:25:28,460 1122 INFO invezomx-stag-15712346 odoo.addons.madkting.models.product: {'yuju_kit': 234383}
# 2024-11-01 23:25:28,460 1122 INFO invezomx-stag-15712346 odoo.addons.madkting.models.product: {'yuju_kit': 333076}
# 2024-11-01 23:25:28,460 1122 INFO invezomx-stag-15712346 odoo.addons.madkting.models.product: {'yuju_kit': 234384}
# 2024-11-01 23:25:28,460 1122 INFO invezomx-stag-15712346 odoo.addons.madkting.models.product: {'yuju_kit': 333077}
# 2024-11-01 23:25:28,460 1122 INFO invezomx-stag-15712346 odoo.addons.madkting.models.product: {'yuju_kit': 234381}
# ...
