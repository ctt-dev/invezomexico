# %%
self.env['ctt_pos_credit_limit.debt_postponement'].search([''])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_900/138054992.py in <module>
# ----> 1 self.env['ctt_pos_credit_limit.debt_postponement'].search([''])
#
# ~/src/odoo/odoo/api.py in __getitem__(self, model_name)
#     547     def __getitem__(self, model_name):
#     548         """ Return an empty recordset from the given model. """
# --> 549         return self.registry[model_name](self, (), ())
#     550
#     551     def __iter__(self):
#
# ~/src/odoo/odoo/modules/registry.py in __getitem__(self, model_name)
#     188     def __getitem__(self, model_name):
#     189         """ Return the model with the given name or raise KeyError if it doesn't exist."""
# --> 190         return self.models[model_name]
#     191
#     192     def __call__(self, model_name):
#
# KeyError: 'ctt_pos_credit_limit.debt_postponement'

# %%
x = self.env['account.move'].search([('partner_id.id','=','6196')])
print(x)
# Out:
# account.move(298, 290, 284, 295, 275, 224, 223)

# %%
acc_move_not_paid = self.env['account.move'].search([('state','=','posted'),('amount_residual','>','0'),('payment_state', 'not in', ('paid','reversed', 'invoicing_legacy')),('partner_id.id','=','6073')])
print(acc_move_not_paid)
# Out:
# account.move(345,)
