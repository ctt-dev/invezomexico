# %%
import urllib.request 
import json  
url = urllib.request.urlopen('https://tiredirectb2b.com.mx/wbsTDApp/General/datas?UserID=3286&Password=LLANTIRED2022') 
data = json.loads(url.read().decode()) 
for x in data["objects"]["ResponseRow"]:
    print(x["Descripcion_Description"])
# Out:
# DES Llanta 265/75R16 116T BLACKHAWK HISCEND-H HT01 AUTO
# DES Llanta 275/45ZR20 110Y XL BLACKHAWK STREET-H HU02 AUTO
# DES Llanta 33X12.50R18LT-10PR 118Q BLACKHAWK HISCEND-H HM01 AUTO
# DES Llanta LT285/70R17-8PR 121/118S BLACKHAWK HISCEND-H HA01 OWL (LETRA CONTORNO BLANCO) AUTO
# Llanta  175/70R14 84T DEXTERO DTR1 AUTO
# Llanta  195/55R15 85V DEXTERO DTR1 AUTO
# Llanta  195/75R14 92T DEXTERO DTR1 AUTO
# Llanta  205/75R14 95T DEXTERO DTR1 AUTO
# Llanta  215/65R15 96T DEXTERO DTR1 AUTO
# Llanta  225/75R15 102T DEXTERO DHT2 AUTO
# Llanta  225/75R15 102T DEXTERO DHT2 AUTO
# Llanta  33X12.50R26LT-10C 114Q HAIDA HD869 AUTO
# Llanta 10R22.5-16C 144/142L LANDY DA802 CAMION
# Llanta 11.00-16-12C FORERUNNER QH621 F-2 OTR
# Llanta 11L-15-10C FORERUNNER QH631 F-3 OTR
# Llanta 11L15-12C BROADPEAK H661 F-3 TL OTR
# Llanta 11L15-12C BROADPEAK H663 I-1 TL OTR
# Llanta 11L16-12C BROADPEAK H663 I-1 TL OTR
# Llanta 11L-16-12C FORERUNNER SKS-1 SKS-1 OTR
# ...
